# %% [markdown]
# # Zomato Restaurant

# %% [markdown]
# # Project Description

# %% [markdown]
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.

# %% [markdown]
# Data Storage:
#
# This problem statement contains two datasets-
#
# Zomato.csv and country_code.csv.
#
# Country_code.csv contains two variables:
# • Country code
# • Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
# • Restaurant Name: Name of the restaurant
#
# • Country Code: Country in which restaurant is located
#
# • City: City in which restaurant is located
#
# • Address: Address of the restaurant
#
# • Locality: Location in the city
#
# • Locality Verbose: Detailed description of the locality
#
# • Longitude: Longitude coordinate of the restaurant&#39;s location
#
# • Latitude: Latitude coordinate of the restaurant&#39;s location
#
# • Cuisines: Cuisines offered by the restaurant
#
# • Average Cost for two: Cost for two people in different currencies
#
# • Currency: Currency of the country
#
# • Has Table booking: yes/no
#
# • Has Online delivery: yes/ no
#
# • Is delivering: yes/ no
#
# • Switch to order menu: yes/no
#
# • Price range: range of price of food
#
# • Aggregate Rating: Average rating out of 5
#
# • Rating color: depending upon the average rating color
#
# • Rating text: text on the basis of rating of rating
#
# • Votes: Number of ratings casted by people

# %% [markdown]
# Problem statement : In this dataset predict 2 things –
#
# 1) Average Cost for two
#
# 2) Price range

# %% [markdown]
# Hint : Use pandas methods to combine all the datasets and then start working on this project.

# %% [markdown]
# Dataset Link-
# •	https://github.com/FlipRoboTechnologies/ML_-Datasets/blob/main/Z_Restaurant/Country-Code.xlsx
# •	https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv

# %% [markdown]
# # EXPLORATION OF DATASET:

# %%
#Importing necessary libraries for analysis:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
#Downloading the raw data and loading into dataframe with the help of pandas library
df1=pd.read_excel(r"C:\Users\sesur\Downloads\Country-Code.xlsx")

# %%
#Downloading the raw data and loading into dataframe with the help of pandas library
df=pd.read_excel(r"C:\Users\sesur\Downloads\zomato (1).xlsx")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
#To know about the no of rows and columns in the dataset
df1.shape
# Out:
# (15, 2)

# %%
#To know about the no of rows and columns in the dataset
df.shape
# Out:
# (9551, 21)

# %%
df1.columns
# Out:
# Index(['Country Code', 'Country'], dtype='object')

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
#To know more about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
cat_col = df.select_dtypes(include=['object']).columns
print("Categorical columns are:",cat_col)
print("\nThe count of categoricdal columns are:",len(cat_col))
# Out:
# Categorical columns are: Index(['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose',
#        'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Rating color',
#        'Rating text'],
#       dtype='object')
#
# The count of categoricdal columns are: 13

# %%
num_col = df.select_dtypes(include=['int64','float64']).columns
print("Numerical columns are:",num_col)
print("\nThe count of Numerical Columns are",len(num_col))
# Out:
# Numerical columns are: Index(['Restaurant ID', 'Country Code', 'Longitude', 'Latitude',
#        'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes'],
#       dtype='object')
#
# The count of Numerical Columns are 8

# %%
below_15=[]
for i in df.columns:
    print("Unique Value count of",i,"column:",len(df[i].unique()))
    if (len(df[i].unique())<15):
        below_15.append(i)
# Out:
# Unique Value count of Restaurant ID column: 9551
# Unique Value count of Restaurant Name column: 7446
# Unique Value count of Country Code column: 15
# Unique Value count of City column: 141
# Unique Value count of Address column: 8918
# Unique Value count of Locality column: 1208
# Unique Value count of Locality Verbose column: 1265
# Unique Value count of Longitude column: 8120
# Unique Value count of Latitude column: 8677
# Unique Value count of Cuisines column: 1826
# Unique Value count of Average Cost for two column: 140
# Unique Value count of Currency column: 12
# Unique Value count of Has Table booking column: 2
# Unique Value count of Has Online delivery column: 2
# Unique Value count of Is delivering now column: 2
# Unique Value count of Switch to order menu column: 1
# Unique Value count of Price range column: 4
# Unique Value count of Aggregate rating column: 33
# Unique Value count of Rating color column: 6
# Unique Value count of Rating text column: 6
# ...

# %%
print("There are",len(below_15),"columns which has unique value count less than 15","\n""The columns are",below_15)
print("\n")
# Out:
# There are 8 columns which has unique value count less than 15
# The columns are ['Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Price range', 'Rating color', 'Rating text']

# %%
df.drop("Restaurant ID",axis=1,inplace=True)

# %% [markdown]
# Not adding another dataframe into single since the main dataframe containes the numerical format of the country code proceeding with it.

# %% [markdown]
# # Identifying the missing values:

# %%
#To know about the missing values in the given dataset
df.isnull().sum()
# Out:
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
plt.figure(figsize = (16,5))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# There is no missing values in the dataset.We can further proceed for the futher data analysis.

# %% [markdown]
# # Statistical Analysis of the dataset:

# %%
#To know more about the statistical description of the dataset
df.describe()
# Out:
#        Country Code    Longitude     Latitude  Average Cost for two  \
# count   9551.000000  9551.000000  9551.000000           9551.000000
# mean      18.365616    64.126574    25.854381           1199.210763
# std       56.750546    41.467058    11.007935          16121.183073
# min        1.000000  -157.948486   -41.330428              0.000000
# 25%        1.000000    77.081343    28.478713            250.000000
# 50%        1.000000    77.191964    28.570469            400.000000
# 75%        1.000000    77.282006    28.642758            700.000000
# max      216.000000   174.832089    55.976980         800000.000000
#
#        Price range  Aggregate rating         Votes
# count  9551.000000       9551.000000   9551.000000
# mean      1.804837          2.666370    156.909748
# std       0.905609          1.516378    430.169145
# min       1.000000          0.000000      0.000000
# 25%       1.000000          2.500000      5.000000
# ...

# %% [markdown]
# Observation:
#
# The count of all the columns are equal.It represents there is no missing values in the dataset.
#
# The mean value is greater than median represents right skewed data.The columns which has this kind of distributions are
# ["Country Code","Average Cost for two","Votes"]
#
# The mean value is lower than median represents left skewed data.The columns which has this kind of distributions are
# ["Longitude","Latitude","Price range","Aggregate rating"]

# %%
num_col = df.select_dtypes(include=['int64','float64']).columns

# %%
#To see the distribution among the columns:
plt.figure(figsize=(20,15),facecolor="pink")
plotnumber=1
for column in num_col:
    if plotnumber<=24:
        ax=plt.subplot(6,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# country_code- There is slight right skewed distribution data
#
# Longitude- There are many peak in the data distribution
#
# Latitude- The 1 major peak and 1 minor peak in the data distribution
#
# Average Cost for two- Extremely right skewed data distribution
#
# Price range many categories of peak in the distribution
#
# Aggregate Rating - two major curves of region in the distribution
#
# votes- extremely right skewed distribution

# %%
df.skew()
# Out:
# Country Code             3.043965
# Longitude               -2.807328
# Latitude                -3.081635
# Average Cost for two    35.477915
# Price range              0.889618
# Aggregate rating        -0.954130
# Votes                    8.807637
# dtype: float64

# %% [markdown]
# sklewness above +/- 0.5  need to treated

# %% [markdown]
# # Visualisation: Univariate and bivariate analysis

# %% [raw]
# Problem statement : In this dataset predict 2 things –
#
# Average Cost for two
#
# Price range

# %% [markdown]
# # Dependent Feature:1 Average Cost for Two

# %% [markdown]
# # Dependent Feature 2: Price range

# %%
cat_col
# Out:
# Index(['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose',
#        'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Rating color',
#        'Rating text'],
#       dtype='object')

# %%
num_col
# Out:
# Index(['Country Code', 'Longitude', 'Latitude', 'Average Cost for two',
#        'Price range', 'Aggregate rating', 'Votes'],
#       dtype='object')

# %%
a=df["Average Cost for two"].unique()
a
# Out:
# array([  1100,   1200,   4000,   1500,   1000,   2000,   6000,    800,
#           900,    700,    850,    600,   3000,   1800,     55,     30,
#            45,     60,     50,     80,     90,    200,    150,    100,
#           230,    240,    350,    140,    170,    120,    250,     40,
#            70,    300,     85,     75,    400,     65,     25,     10,
#             0,     20,     35,      7,    270,    500,    430,    315,
#           220,     95,    190,    260,    180,    330,    280,    160,
#           285,    130,    110,   2500,   3600,    550,   1400,    450,
#           950,    650,   1300,   2400,   1600,   2200,    750,   1700,
#          1250,   1900,   2700,   3500,   5000,   2300,   1750,   3200,
#          2100,   1850,   4500,   3300,   1350,   1650,   1950,   1050,
#           290,   1450,   2800,   3650,   4800,   1550,    720,   6500,
#          7000,   1150,   2900,   2600,   4700,   3700,   3800,   4100,
# ...

# %% [markdown]
# minimum value=0 and maximum value=800000

# %%
#Analysing Restaurant name vs Average cost for two
df.groupby('Restaurant Name')['Average Cost for two'].sum().nlargest(20).plot.bar()
# Out:
# <Axes: xlabel='Restaurant Name'>

# %%
df.groupby('City')['Average Cost for two'].sum().nlargest(20).plot.bar()
# Out:
# <Axes: xlabel='City'>

# %%
df.groupby('Locality')['Average Cost for two'].sum().nlargest(20).plot.bar()
# Out:
# <Axes: xlabel='Locality'>

# %%
df.groupby('Locality Verbose')['Average Cost for two'].sum().nlargest(20).plot.bar()
# Out:
# <Axes: xlabel='Locality Verbose'>

# %%
df.groupby('Cuisines')['Average Cost for two'].sum().nlargest(20).plot.bar()
# Out:
# <Axes: xlabel='Cuisines'>

# %%
df.groupby('Currency')['Average Cost for two'].sum().nlargest(20).plot.bar()
# Out:
# <Axes: xlabel='Currency'>

# %%
df.groupby('Has Table booking')['Average Cost for two'].sum().nlargest(20).plot.bar()
# Out:
# <Axes: xlabel='Has Table booking'>

# %%
df.groupby('Has Online delivery')['Average Cost for two'].sum().nlargest(20).plot.bar()
# Out:
# <Axes: xlabel='Has Online delivery'>

# %%
df.groupby('Is delivering now')['Average Cost for two'].sum().nlargest(20).plot.bar()
# Out:
# <Axes: xlabel='Is delivering now'>

# %%
df.groupby('Switch to order menu')['Average Cost for two'].sum().nlargest(20).plot.bar()
# Out:
# <Axes: xlabel='Switch to order menu'>

# %%
df.groupby('Rating color')['Average Cost for two'].sum().nlargest(20).plot.bar()
# Out:
# <Axes: xlabel='Rating color'>

# %%
df.groupby('Rating text')['Average Cost for two'].sum().nlargest(20).plot.bar()
# Out:
# <Axes: xlabel='Rating text'>

# %% [markdown]
# From all these observation we can see the Average cost for two how affects other columns which is having higher and lower data section

# %% [markdown]
# # Encoding:

# %%
cat_col
# Out:
# Index(['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose',
#        'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Rating color',
#        'Rating text'],
#       dtype='object')

# %% [markdown]
# These are the columns which has object datatype.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %% [raw]
# Unique Value count of Has Table booking column: 2
# Unique Value count of Has Online delivery column: 2
# Unique Value count of Is delivering now column: 2

# %%
#Replacing the Gender column:
df.replace({
    "Has Table booking":{"Yes":1,"No":0}},inplace=True)

# %%
#Replacing the has One delivery column:
df.replace({
    "Has Online delivery":{"Yes":1,"No":0}},inplace=True)

# %%
#Replacing the has Is delivering now column:
df.replace({
    "Is delivering now":{"Yes":1,"No":0}},inplace=True)

# %%
df.replace({
    "Is delivering now":{"Yes":1,"No":0}},inplace=True)

# %% [markdown]
# Till this the columns have only yes or no replacing it with 0 and 1.

# %%
df["Switch to order menu"].unique()
# Out:
# array(['No'], dtype=object)

# %%
df.drop("Switch to order menu",axis=1,inplace=True)

# %% [markdown]
# Dropping the Switch to order Menu since it has only one unique value not gonna contribute for the output.

# %%
df["Rating text"].unique()
# Out:
# array(['Excellent', 'Very Good', 'Good', 'Average', 'Not rated', 'Poor'],
#       dtype=object)

# %% [markdown]
# Rating Text column follows the order so encoding with ordinal encoder

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
encoder = OrdinalEncoder(categories=[['Poor','Not rated','Average', 'Good','Very Good','Excellent']])
df['Rating text'] = encoder.fit_transform(df[['Rating text']])

# %%
df["Rating text"].unique()
# Out:
# array([5., 4., 3., 2., 1., 0.])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       9551 non-null   object
#  1   Country Code          9551 non-null   int64
#  2   City                  9551 non-null   object
#  3   Address               9551 non-null   object
#  4   Locality              9551 non-null   object
#  5   Locality Verbose      9551 non-null   object
#  6   Longitude             9551 non-null   float64
#  7   Latitude              9551 non-null   float64
#  8   Cuisines              9542 non-null   object
#  9   Average Cost for two  9551 non-null   int64
#  10  Currency              9551 non-null   object
#  11  Has Table booking     9551 non-null   int64
#  12  Has Online delivery   9551 non-null   int64
#  13  Is delivering now     9551 non-null   int64
#  14  Price range           9551 non-null   int64
# ...

# %%
df.drop(["Rating color","Locality","Restaurant Name"],axis=1,inplace=True)

# %%
cat_col = df.select_dtypes(include=['object']).columns

# %%
from sklearn.preprocessing import LabelEncoder,TargetEncoder
le=LabelEncoder()
df["City"]=le.fit_transform(df["City"])
df["Cuisines"]=le.fit_transform(df["Cuisines"])
df["Currency"]=le.fit_transform(df["Currency"])
df["Locality Verbose"]=le.fit_transform(df["Locality Verbose"])

# %%
df["Address"]=le.fit_transform(df["Address"])

# %% [markdown]
# With this all the categorical columns are converted into numerical column

# %% [markdown]
# # Corelation:

# %%
df.corr()
# Out:
#                       Country Code      City   Address  Locality Verbose  \
# Country Code              1.000000 -0.181728 -0.220342         -0.117543
# City                     -0.181728  1.000000 -0.019763          0.093142
# Address                  -0.220342 -0.019763  1.000000          0.160495
# Locality Verbose         -0.117543  0.093142  0.160495          1.000000
# Longitude                -0.698299  0.117391  0.185801          0.084342
# Latitude                  0.019792 -0.004301 -0.038654         -0.020905
# Cuisines                 -0.129451  0.025764  0.022833          0.005482
# Average Cost for two      0.043225 -0.028838  0.022749         -0.011852
# Currency                 -0.033466 -0.071996  0.069499          0.022966
# Has Table booking        -0.061682 -0.003762  0.006428         -0.065132
# Has Online delivery      -0.154605  0.012723  0.029874         -0.031766
# Is delivering now        -0.018291 -0.014039  0.031267         -0.007353
# ...

# %%
plt.figure(figsize=(25,20))
sns.heatmap(df.corr(),annot=True,linewidths=.25)
# Out:
# <Axes: >

# %% [markdown]
# We can see the corelation using the heatmap.

# %% [markdown]
# # Skewness handling

# %%
plt.figure(figsize=(18,15))
for i in enumerate(df.columns):
    plt.subplot(8,4,i[0]+1)
    sns.distplot(df[i[1]],color='r')

# %%
Y1=df["Average Cost for two"].apply(lambda value: "affordable" if value<=10000  else "Expensive")

# %%
Y1=df["Average Cost for two"].apply(lambda value: 1 if value<=10000  else 0)

# %% [raw]
# Affordable as 1 Expensive as 0

# %%
Y1.value_counts()
# Out:
# 1    9530
# 0      21
# Name: Average Cost for two, dtype: int64

# %%
Y1.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
Y=df["Price range"]

# %%
df.skew()
# Out:
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality Verbose        -0.183064
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.305484
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating text              0.461232
# Votes                    8.807637
# dtype: float64

# %% [markdown]
# skewness more than+/- 0.5 will we treated

# %%
from sklearn.preprocessing import power_transform

df[['Average Cost for two']]=power_transform(df[['Average Cost for two']],method='yeo-johnson')
df[['Votes']]=power_transform(df[['Votes']],method='yeo-johnson')

# %%
df.skew()
# Out:
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality Verbose        -0.183064
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.305484
# Average Cost for two     0.142365
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating text              0.461232
# Votes                   -0.004029
# dtype: float64

# %% [markdown]
# With the help of power tranform some of the skewness is reduced

# %% [markdown]
# # Outliers:

# %%
#To see the outliers among the columns:
plt.figure(figsize=(20,15),facecolor="pink")
plotnumber=1
for column in df.columns:
    if plotnumber<=18:
        ax=plt.subplot(6,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# There are some outliers in the dataset.

# %% [markdown]
# # outliers removal

# %% [markdown]
# # zscore

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
print(np.where(z>3))
z_scoredf=df[(z<3).all(axis=1)]
print("with outliers::",df.shape)
print("After removing outliers::",z_scoredf.shape)
# Out:
# (array([   0,    1,    2, ..., 9549, 9550, 9550], dtype=int64), array([8, 8, 8, ..., 8, 0, 8], dtype=int64))
# with outliers:: (9551, 16)
# After removing outliers:: (8551, 16)

# %% [markdown]
# # IQR

# %%
from scipy import stats 
IQR = stats.iqr(df) 
IQR
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQRdf= df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
print(IQRdf.shape)
# Out:
# (2200, 16)

# %%
#Choosing zscore for the outlier removal: 
z_scoredf=df

# %% [markdown]
# When using IQR there is huge dataloss so choosing the zscore for the outlier removal.

# %% [markdown]
# Seperating to check the imbalancement in the dataset.

# %% [markdown]
# # Checking for the Imbalanced dataset in dependent feature:

# %%
Y.value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()

# %% [markdown]
# # Splitting The Dataset Into Feature and Target:

# %%
#Importing the neccessary libraries and model for further creation of the model:
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.linear_model import RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score
from sklearn.model_selection import cross_val_score

# %%
X=df

# %%
X.shape , Y.shape
# Out:
# ((9551, 16), (9551,))

# %%
Y.value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %% [markdown]
# Now,Standardising the independent features.

# %% [markdown]
# # Standardisation:

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(X)

# %%
# best Random_state
maxaccu=0
maxRS=0

for i in range(0,200):
    x_train,x_test,y_train,y_test= train_test_split(x_scaled,Y,random_state=i,test_size=.20)
    LR= LogisticRegression()
    LR.fit(x_train,y_train)
    pred= LR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxRS=i
print("Best accuracy is ",maxaccu,"on Random State =",maxRS)
# Out:
# Best accuracy is  1.0 on Random State = 0

# %%
x_train,x_test,y_train,y_test= train_test_split(x_scaled,Y,random_state=maxRS,test_size=.20)

# %% [markdown]
# # Model Selection:

# %%
LR_model= LogisticRegression()
RD_model= RidgeClassifier()
DT_model= DecisionTreeClassifier()
SV_model= SVC()
KNR_model= KNeighborsClassifier()
RFR_model= RandomForestClassifier()
SGH_model= SGDClassifier()
Bag_model=BaggingClassifier()
ADA_model=AdaBoostClassifier()
GB_model= GradientBoostingClassifier()

model=[LR_model,RD_model,DT_model,SV_model,KNR_model,RFR_model,SGH_model,Bag_model,ADA_model,GB_model ]

# %%
for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    pred= m.predict(x_test)
    print('Accuracy_Score of ',m, 'is', accuracy_score(y_test,pred)*100)
    print('Confusion Matrix of ',m,' is \n', confusion_matrix(y_test,pred) )
    print(classification_report(y_test,pred))
    print('*'*50)
# Out:
# Accuracy_Score of  LogisticRegression() is 100.0
# Confusion Matrix of  LogisticRegression()  is
#  [[899   0   0   0]
#  [  0 623   0   0]
#  [  0   0 266   0]
#  [  0   0   0 123]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       899
#            2       1.00      1.00      1.00       623
#            3       1.00      1.00      1.00       266
#            4       1.00      1.00      1.00       123
#
#     accuracy                           1.00      1911
#    macro avg       1.00      1.00      1.00      1911
# weighted avg       1.00      1.00      1.00      1911
#
# **************************************************
# Accuracy_Score of  RidgeClassifier() is 77.34170591313449
# Confusion Matrix of  RidgeClassifier()  is
#  [[897   2   0   0]
#  [192 419  12   0]
#  [  0 107 151   8]
#  [  0  29  83  11]]
#               precision    recall  f1-score   support
#
#            1       0.82      1.00      0.90       899
# ...

# %% [markdown]
# # Cross Validation

# %%
for i in model:
    print('Accuracy_Score of ',i, 'is', accuracy_score(y_test,i.predict(x_test))*100)
    print("cross Validation accuracy score of ",i ," is ",cross_val_score(i,X,Y,cv=5, scoring='accuracy').mean()*100)
    print("\n")
# Out:
# Accuracy_Score of  LogisticRegression() is 100.0
# cross Validation accuracy score of  LogisticRegression()  is  43.01136161270791
#
#
# Accuracy_Score of  RidgeClassifier() is 77.34170591313449
# cross Validation accuracy score of  RidgeClassifier()  is  76.11776406092038
#
#
# Accuracy_Score of  DecisionTreeClassifier() is 100.0
# cross Validation accuracy score of  DecisionTreeClassifier()  is  100.0
#
#
# Accuracy_Score of  SVC() is 99.63369963369964
# cross Validation accuracy score of  SVC()  is  45.06319160769423
#
#
# Accuracy_Score of  KNeighborsClassifier() is 95.6567242281528
# cross Validation accuracy score of  KNeighborsClassifier()  is  nan
#
#
# Accuracy_Score of  RandomForestClassifier() is 100.0
# cross Validation accuracy score of  RandomForestClassifier()  is  99.98953427524857
#
#
# Accuracy_Score of  SGDClassifier() is 90.52851909994767
# cross Validation accuracy score of  SGDClassifier()  is  45.753973276785544
#
#
# ...

# %% [markdown]
# # Top model 1:

# %% [markdown]
# Accuracy_Score of  AdaBoostClassifier() is 86.08058608058609
#
# cross Validation accuracy score of  AdaBoostClassifier()  is  85.25808970386383

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(ADA_model,"Zomato_price range_Prediction.pkl")
# Out:
# ['Zomato_price range_Prediction.pkl']

# %% [markdown]
# Dependent Feature :Average Cost for Two
#
# if the cost for two is below 15,000 it comes under affordable and if it above expensive

# %%
X.columns
# Out:
# Index(['Country Code', 'City', 'Address', 'Locality Verbose', 'Longitude',
#        'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Price range', 'Aggregate rating', 'Rating text', 'Votes'],
#       dtype='object')

# %%
X=df.drop("Average Cost for two",axis=1)

# %%
Y1.shape
# Out:
# (9551,)

# %%
Y1.value_counts()
# Out:
# 1    9530
# 0      21
# Name: Average Cost for two, dtype: int64

# %%
Y1.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()

# %%
X,Y1=sm.fit_resample(X,Y1)

# %%
len(Y1.unique())
# Out:
# 2

# %% [markdown]
# Choosing the random State:

# %%
# best Random_state
maxaccu=0
maxRs=0

for i in range(0,200):
    x_train,x_test,y_train,y_test= train_test_split(X,Y1,random_state=i,test_size=.20)
    LR= LogisticRegression()
    LR.fit(x_train,y_train)
    pred= LR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxRs=i
print("Best accuracy is ",maxaccu,"on Random State =",maxRs)
# Out:
# Best accuracy is  0.9897691500524659 on Random State = 125

# %%
x_train,x_test,y_train,y_test= train_test_split(X,Y1,random_state=maxRs,test_size=.20)

# %%
LR_model= LogisticRegression()
RD_model= RidgeClassifier()
DT_model= DecisionTreeClassifier()
SV_model= SVC()
KNR_model= KNeighborsClassifier()
RFR_model= RandomForestClassifier()
SGH_model= SGDClassifier()
Bag_model=BaggingClassifier()
ADA_model=AdaBoostClassifier()
GB_model= GradientBoostingClassifier()

model=[LR_model,RD_model,DT_model,SV_model,KNR_model,RFR_model,SGH_model,Bag_model,ADA_model,GB_model ]

# %%
for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    pred= m.predict(x_test)
    print('Accuracy_Score of ',m, 'is', accuracy_score(y_test,pred)*100)
    print('Confusion Matrix of ',m,' is \n', confusion_matrix(y_test,pred) )
    print(classification_report(y_test,pred))
    print('*'*50)
# Out:
# Accuracy_Score of  LogisticRegression() is 98.9769150052466
# Confusion Matrix of  LogisticRegression()  is
#  [[1936    0]
#  [  39 1837]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1936
#            1       1.00      0.98      0.99      1876
#
#     accuracy                           0.99      3812
#    macro avg       0.99      0.99      0.99      3812
# weighted avg       0.99      0.99      0.99      3812
#
# **************************************************
# Accuracy_Score of  RidgeClassifier() is 98.81951731374606
# Confusion Matrix of  RidgeClassifier()  is
#  [[1936    0]
#  [  45 1831]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1936
#            1       1.00      0.98      0.99      1876
#
#     accuracy                           0.99      3812
#    macro avg       0.99      0.99      0.99      3812
# ...

# %%
for i in model:
    print('Accuracy_Score of ',i, 'is', accuracy_score(y_test,i.predict(x_test))*100)
    print("cross Validation accuracy score of ",i ," is ",cross_val_score(i,X,Y1,cv=5, scoring='accuracy').mean()*100)
    print('*'*50)
# Out:
# Accuracy_Score of  LogisticRegression() is 98.9769150052466
# cross Validation accuracy score of  LogisticRegression()  is  97.96432318992656
# **************************************************
# Accuracy_Score of  RidgeClassifier() is 98.81951731374606
# cross Validation accuracy score of  RidgeClassifier()  is  95.40398740818468
# **************************************************
# Accuracy_Score of  DecisionTreeClassifier() is 100.0
# cross Validation accuracy score of  DecisionTreeClassifier()  is  98.55718782791186
# **************************************************
# Accuracy_Score of  SVC() is 98.2423924449108
# cross Validation accuracy score of  SVC()  is  98.20041972717732
# **************************************************
# Accuracy_Score of  KNeighborsClassifier() is 98.74081846799581
# cross Validation accuracy score of  KNeighborsClassifier()  is  97.66526757607556
# **************************************************
# ...

# %% [markdown]
# # Top model : 1

# %% [raw]
# Accuracy_Score of  LogisticRegression() is 98.9769150052466
#
# cross Validation accuracy score of  LogisticRegression()  is  97.96432318992656

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(LR_model,"Logistic Regression model_Prediction.pkl")
# Out:
# ['Logistic Regression model_Prediction.pkl']

# %% [markdown]
# End of the project
