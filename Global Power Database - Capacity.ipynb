# %% [markdown]
# # Global Power Plant Database

# %% [markdown]
# # Project Description

# %% [markdown]
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 14,000 power plants from 3 countries(USA, AUS, INDIA) and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.

# %% [markdown]
# # Key attributes of the database

# %% [markdown]
# The database includes the following indicators:
#
# • country (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5]
#
# • country_long (text): longer form of the country designation
#
# • name (text): name or title of the power plant, generally in Romanized form
#
# • gppd_idnr (text): 10 or 12 character identifier for the power plant
#
# • capacity_mw (number): electrical generating capacity in megawatts
#
# • latitude (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# • longitude (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# • primary_fuel (text): energy source used in primary electricity generation or export
#
# • other_fuel1 (text): energy source used in electricity generation or export
#
# • other_fuel2 (text): energy source used in electricity generation or export
#
# • other_fuel3 (text): energy source used in electricity generation or export
#
# • commissioning_year (number): year of plant operation, weighted by unit-capacity when data is available
#
# • owner (text): majority shareholder of the power plant, generally in Romanized form
#
# • source (text): entity reporting the data; could be an organization, report, or document, generally in Romanized form
#
# • url (text): web document corresponding to the source field
#
# • geolocation_source (text): attribution for geolocation information
#
# • wepp_id (text): a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
#
# • year_of_capacity_data (number): year the capacity information was reported
#
# • generation_gwh_2013 (number): electricity generation in gigawatt-hours reported for the year 2013
#
# • generation_gwh_2014 (number): electricity generation in gigawatt-hours reported for the year 2014
#
# • generation_gwh_2015 (number): electricity generation in gigawatt-hours reported for the year 2015
#
# • generation_gwh_2016 (number): electricity generation in gigawatt-hours reported for the year 2016
#
# • generation_gwh_2017 (number): electricity generation in gigawatt-hours reported for the year 2017
#
# • generation_gwh_2018 (number): electricity generation in gigawatt-hours reported for the year 2018
#
# • generation_gwh_2019 (number): electricity generation in gigawatt-hours reported for the year 2019
#
# • generation_data_source (text): attribution for the reported generation information
#
# • estimated_generation_gwh_2013 (number): estimated electricity generation in gigawatt-hours for the year 2013
#
# • estimated_generation_gwh_2014 (number): estimated electricity generation in gigawatt-hours for the year 2014
#
# • estimated_generation_gwh_2015 (number): estimated electricity generation in gigawatt-hours for the year 2015
#
# • estimated_generation_gwh_2016 (number): estimated electricity generation in gigawatt-hours for the year 2016
#
# • estimated_generation_gwh_2017 (number): estimated electricity generation in gigawatt-hours for the year 2017
#
# • 'estimated_generation_note_2013` (text): label of the model/method used to estimate generation for the year 2013
#
# • estimated_generation_note_2014 (text): label of the model/method used to estimate generation for the year 2014
#
# • estimated_generation_note_2015 (text): label of the model/method used to estimate generation for the year 2015
#
# • estimated_generation_note_2016 (text): label of the model/method used to estimate generation for the year 2016
#
# • estimated_generation_note_2017 (text): label of the model/method used to estimate generation for the year 2017

# %% [markdown]
# Fuel Type Aggregation We define the "Fuel Type" attribute of our database based on common fuel categories. Prediction : Make two prediction 1) Primary Fuel 2) capacity_mw
#
# Hint : Use pandas methods to combine all the datasets and then start working on this project.

# %% [markdown]
# # EXPLORATION OF DATASET:

# %%
#Importing necessary libraries for analysis:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
#Downloading the raw data and loading into dataframe with the help of pandas library:
df1=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Global%20Power%20Plant%20Database/database_AUS.csv")

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Global%20Power%20Plant%20Database/database_IND.csv")

# %%
df3=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Global%20Power%20Plant%20Database/database_USA.csv")

# %%
#For viewing the first 5 columns in given dataset
df1.head(5)
# Out:
#   country country_long                   name   gppd_idnr  capacity_mw  \
# 0     AUS    Australia       Adelaide Airport  AUS0000433         0.11
# 1     AUS    Australia   Adelaide Showgrounds  AUS0000432         1.00
# 2     AUS    Australia       Albany Wind Farm  AUS0000065        21.60
# 3     AUS    Australia  Alice Springs Airport  AUS0000469         0.24
# 4     AUS    Australia           Amcor Gawler  AUS0000231         4.00
#
#    latitude  longitude primary_fuel  other_fuel1  other_fuel2  ...  \
# 0  -34.9387   138.5377        Solar          NaN          NaN  ...
# 1  -34.9453   138.5882        Solar          NaN          NaN  ...
# 2  -35.0641   117.7977         Wind          NaN          NaN  ...
# 3  -23.7966   133.8971        Solar          NaN          NaN  ...
# 4  -34.5509   138.7659          Oil          NaN          NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0                 2019.0                  NaN                 NaN
# 1                 2019.0                  NaN                 NaN
# 2                 2019.0            89.595278          102.642778
# 3                 2019.0                  NaN                 NaN
# 4                 2019.0                  NaN                 NaN
#
#   generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2           96.555556           95.872778           85.900278
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    generation_gwh_2018  generation_gwh_2019            generation_data_source  \
# 0                  NaN                  NaN                               NaN
# 1                  NaN                  NaN                               NaN
# 2            92.682222                  NaN  Australia Clean Energy Regulator
# 3                  NaN                  NaN                               NaN
# 4                  NaN                  NaN                               NaN
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 27 columns]

# %%
#For viewing the first 5 columns in  dataset
df2.head(5)
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                    NaN                  NaN                 NaN
# 3                 2019.0              2.41461          617.789264
# 4                 2019.0                  NaN         3035.550000
#
#   generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3             843.747          886.004428          663.774500
# 4            5916.370         6243.000000         5385.579736
#
#    generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3           626.239128                  NaN  Central Electricity Authority
# 4          7279.000000                  NaN  Central Electricity Authority
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 27 columns]

# %%
#For viewing the first 5 columns in given  dataset
df3.head(5)
# Out:
#   country              country_long                            name  \
# 0     USA  United States of America  10 Briggs Solar NG  LLC (East)
# 1     USA  United States of America      100 Brook Hill Drive Solar
# 2     USA  United States of America      1001 Ebenezer Church Solar
# 3     USA  United States of America             1008 Matthews Solar
# 4     USA  United States of America               1009 Yadkin Solar
#
#     gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0  USA0062781          0.0   41.6327   -71.4963          NaN         NaN
# 1  USA0063292          2.0   41.0930   -73.9828        Solar         NaN
# 2  USA0063444          0.0   36.2838   -80.8434          NaN         NaN
# 3  USA0063447          0.0   36.2167   -80.5525          NaN         NaN
# 4  USA0063445          0.0   36.1475   -80.6561          NaN         NaN
#
#   other_fuel2  ... year_of_capacity_data  generation_gwh_2013  \
# 0         NaN  ...                2019.0                  NaN
# 1         NaN  ...                2019.0                  NaN
# 2         NaN  ...                2019.0                  NaN
# 3         NaN  ...                2019.0                  NaN
# 4         NaN  ...                2019.0                  NaN
#
#   generation_gwh_2014 generation_gwh_2015 generation_gwh_2016  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#   generation_gwh_2017  generation_gwh_2018  generation_gwh_2019  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                2.467
# 2                 NaN                  NaN                  NaN
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#                    generation_data_source  estimated_generation_gwh
# 0                                     NaN                       NaN
# 1  U.S. Energy Information Administration                       NaN
# 2                                     NaN                       NaN
# 3                                     NaN                       NaN
# 4                                     NaN                       NaN
#
# [5 rows x 27 columns]

# %%
df_temp=df2.append(df3)

# %%
df=df_temp.append(df1)

# %%
df.shape
# Out:
# (13298, 27)

# %%
df1.shape,df2.shape,df3.shape
# Out:
# ((512, 27), (907, 27), (11879, 27))

# %%
df1.shape[0]+df2.shape[0]+df3.shape[0]
# Out:
# 13298

# %%
cat_col = df.select_dtypes(include=['object']).columns
print("Categorical columns are:",cat_col)
print("\nThe count of categoricdal columns are:",len(cat_col))
# Out:
# Categorical columns are: Index(['country', 'country_long', 'name', 'gppd_idnr', 'primary_fuel',
#        'other_fuel1', 'other_fuel2', 'other_fuel3', 'owner', 'source', 'url',
#        'geolocation_source', 'generation_gwh_2019', 'generation_data_source'],
#       dtype='object')
#
# The count of categoricdal columns are: 14

# %%
num_col = df.select_dtypes(include=['int64','float64']).columns
print("Numerical columns are:",num_col)
print("\nThe count of Numerical Columns are",len(num_col))
# Out:
# Numerical columns are: Index(['capacity_mw', 'latitude', 'longitude', 'commissioning_year', 'wepp_id',
#        'year_of_capacity_data', 'generation_gwh_2013', 'generation_gwh_2014',
#        'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
#        'generation_gwh_2018', 'estimated_generation_gwh'],
#       dtype='object')
#
# The count of Numerical Columns are 13

# %%
#Unique values in the column
below_16=[]
for i in df.columns:
    print("Unique Value count of",i,"column:",len(df[i].unique()))
    if (len(df[i].unique())<16):
        below_16.append(i)
# Out:
# Unique Value count of country column: 3
# Unique Value count of country_long column: 3
# Unique Value count of name column: 13266
# Unique Value count of gppd_idnr column: 13298
# Unique Value count of capacity_mw column: 2305
# Unique Value count of latitude column: 12386
# Unique Value count of longitude column: 12734
# Unique Value count of primary_fuel column: 15
# Unique Value count of other_fuel1 column: 13
# Unique Value count of other_fuel2 column: 12
# Unique Value count of other_fuel3 column: 10
# Unique Value count of commissioning_year column: 1937
# Unique Value count of owner column: 5878
# Unique Value count of source column: 206
# Unique Value count of url column: 325
# Unique Value count of geolocation_source column: 6
# Unique Value count of wepp_id column: 1
# Unique Value count of year_of_capacity_data column: 2
# Unique Value count of generation_gwh_2013 column: 5617
# Unique Value count of generation_gwh_2014 column: 6307
# Unique Value count of generation_gwh_2015 column: 6693
# Unique Value count of generation_gwh_2016 column: 7151
# Unique Value count of generation_gwh_2017 column: 7631
# Unique Value count of generation_gwh_2018 column: 8041
# Unique Value count of generation_gwh_2019 column: 8369
# Unique Value count of generation_data_source column: 4
# Unique Value count of estimated_generation_gwh column: 1

# %%
for i in below_16:
    print("Unique values of these columns:",i,"-",df[i].unique())
# Out:
# Unique values of these columns: country - ['IND' 'USA' 'AUS']
# Unique values of these columns: country_long - ['India' 'United States of America' 'Australia']
# Unique values of these columns: primary_fuel - ['Solar' 'Coal' 'Wind' 'Gas' 'Hydro' 'Biomass' 'Oil' 'Nuclear' nan 'Waste'
#  'Storage' 'Cogeneration' 'Geothermal' 'Petcoke' 'Other']
# Unique values of these columns: other_fuel1 - [nan 'Oil' 'Cogeneration' 'Gas' 'Waste' 'Solar' 'Coal' 'Biomass' 'Hydro'
#  'Storage' 'Other' 'Petcoke' 'Wind']
# Unique values of these columns: other_fuel2 - [nan 'Oil' 'Gas' 'Other' 'Solar' 'Biomass' 'Waste' 'Storage' 'Hydro'
#  'Coal' 'Wind' 'Petcoke']
# Unique values of these columns: other_fuel3 - [nan 'Other' 'Gas' 'Solar' 'Biomass' 'Wind' 'Hydro' 'Waste' 'Storage'
#  'Oil']
# Unique values of these columns: geolocation_source - ['National Renewable Energy Laboratory' 'WRI' nan 'Industry About'
#  'U.S. Energy Information Administration'
#  'Australian Renewable Energy Mapping Infrastructure']
# Unique values of these columns: wepp_id - [nan]
# Unique values of these columns: year_of_capacity_data - [  nan 2019.]
# Unique values of these columns: generation_data_source - [nan 'Central Electricity Authority'
#  'U.S. Energy Information Administration'
#  'Australia Clean Energy Regulator']
# Unique values of these columns: estimated_generation_gwh - [nan]

# %% [markdown]
# From this observation dropping the column which has 1 unique and 2 unique values-[nan,value].The country long column is just the expansion of the country column so removing that column,

# %%
df.drop(columns=["estimated_generation_gwh","wepp_id","year_of_capacity_data","country_long","generation_data_source"], axis=1, inplace=True)

# %% [markdown]
# We can futher process for the further analysis.

# %% [markdown]
# # Identifying the missing values:

# %%
#Finding the missing values
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values],axis =1,keys =['Missing Values','% Missing data']))
# Out:
#                      Missing Values  % Missing data
# other_fuel3                   13206       99.308167
# other_fuel2                   13028       97.969619
# other_fuel1                   11670       87.757558
# generation_gwh_2013            6128       46.082118
# generation_gwh_2014            5764       43.344864
# generation_gwh_2015            5305       39.893217
# generation_gwh_2016            4597       34.569108
# generation_gwh_2017            4006       30.124831
# generation_gwh_2019            3520       26.470146
# generation_gwh_2018            3440       25.868552
# commissioning_year             2644       19.882689
# primary_fuel                   2004       15.069935
# owner                           593        4.459317
# longitude                        78        0.586554
# latitude                         78        0.586554
# geolocation_source               23        0.172958
# capacity_mw                       6        0.045120
# url                               0        0.000000
# source                            0        0.000000
# name                              0        0.000000
# gppd_idnr                         0        0.000000
# country                           0        0.000000

# %% [markdown]
# These columns have more than 85% of the missing data in the columns. So removing those columns.

# %%
# Dropping empty columns:
df.drop(columns=['other_fuel3','other_fuel1','other_fuel2'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# country                   0
# name                      0
# gppd_idnr                 0
# capacity_mw               6
# latitude                 78
# longitude                78
# primary_fuel           2004
# commissioning_year     2644
# owner                   593
# source                    0
# url                       0
# geolocation_source       23
# generation_gwh_2013    6128
# generation_gwh_2014    5764
# generation_gwh_2015    5305
# generation_gwh_2016    4597
# generation_gwh_2017    4006
# generation_gwh_2018    3440
# generation_gwh_2019    3520
# dtype: int64

# %% [markdown]
# From we can see there so many missing values when using dropna there is huge dataloss so going with the imputation for categorical columns filling with the mode and for the numerical column filling with the mean column.

# %%
#seperating numerical and categorical column
cat_col = df.select_dtypes(include=['object']).columns
num_col = df.select_dtypes(include=['int64','float64']).columns
#seperating numerical and categorical column

# %%
#imputing the missing value with mode:For categorical column
for i in cat_col:
    df[i].fillna(df[i].mode()[0],inplace=True)

# %%
#Imputing the missing value with median:For Numerical Column
for i in num_col:
    df[i].fillna(df[i].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# country                0
# name                   0
# gppd_idnr              0
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# commissioning_year     0
# owner                  0
# source                 0
# url                    0
# geolocation_source     0
# generation_gwh_2013    0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# generation_gwh_2018    0
# generation_gwh_2019    0
# dtype: int64

# %% [markdown]
# Handled the missing values.

# %% [markdown]
# # Statistical Analysis of the dataset:

# %%
#To know more about the statistical description of the dataset
df.describe().T
# Out:
#                        count         mean          std        min         25%  \
# capacity_mw          13298.0   117.688075   347.098888     0.0000     1.50000
# latitude             13298.0    35.072784    15.400938   -42.8883    33.91425
# longitude            13298.0   -73.873706    62.692711  -171.7124  -104.58340
# commissioning_year   13298.0  2000.136409    21.851731  1896.0000  1993.50000
# generation_gwh_2013  13298.0   313.618733  1515.223100  -947.6000    15.06350
# generation_gwh_2014  13298.0   369.819541  1678.509435  -989.6190    12.71875
# generation_gwh_2015  13298.0   378.520539  1690.892264  -864.4280     9.14075
# generation_gwh_2016  13298.0   372.907810  1678.766047  -768.6200     6.40025
# generation_gwh_2017  13298.0   376.112976  1689.845051  -934.9440     5.03425
# generation_gwh_2018  13298.0   383.981725  1704.730034  -982.6220     4.08850
#
#                              50%          75%         max
# capacity_mw             5.500000    52.650000   6809.0000
# latitude               38.389750    42.166025    425.2461
# longitude             -87.346000   -75.535425    153.4341
# commissioning_year   2008.000000  2014.000000   2020.0000
# generation_gwh_2013    21.384500    27.758750  31431.0800
# generation_gwh_2014    22.241000    34.949500  32320.9170
# generation_gwh_2015    19.504000    40.148450  32525.5950
# generation_gwh_2016    15.410278    45.893500  32377.4770
# generation_gwh_2017    13.433861    51.903250  35116.0000
# generation_gwh_2018    12.308500    56.527000  35136.0000

# %% [markdown]
# observation:
#
# 1]The count of the all columns are equal.There is no missing values in the dataset.
#
# 2]The Mean is greater than median represents the distribution of data is right skewed.The columns which has this kind of distribution.
#
# 3]The mean is lower than median repesents the distribution of data is left skewed.The columns which has this kind of distribution are [latitude,longitude,commissioning_year,
#
# 4]The mean is equal to median-[generation_gwh_2013,generation_gwh_2014,generation_gwh_2016,generation_gwh_2017,generation_gwh_2018]

# %%
#To see the distribution among the columns:
plt.figure(figsize=(20,15),facecolor="pink")
plotnumber=1
for column in num_col:
    if plotnumber<=10:
        ax=plt.subplot(5,2,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Observation:
#
# longitude- There are two slopes in the data distribution.
# latitude- There are two slopes in the data distribution
#
# All other columns have some symmentric distribution of the data.

# %% [markdown]
# # Visualisation: Univariate and bivariate analysis

# %%
df['country'].unique()
# Out:
# array(['IND', 'USA', 'AUS'], dtype=object)

# %%
df["country"].value_counts()
# Out:
# USA    11879
# IND      907
# AUS      512
# Name: country, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x="country",data=df)
plt.title("Country Column")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x="country",hue="primary_fuel",data=df)
plt.title("Country vs primary Fuel")
plt.show()

# %% [markdown]
# From this visulaisation we see that Solar is the primary fuel in the USA.Wind is the primary fuel in india,Hydro is the primary fuel in AUS

# %%
df['gppd_idnr'].unique()
# Out:
# array(['WRI1020239', 'WRI1019881', 'WRI1026669', ..., 'AUS0000465',
#        'AUS0000257', 'AUS0000218'], dtype=object)

# %%
# Dropping columns
df.drop(columns=["gppd_idnr"],axis=1,inplace=True)

# %% [markdown]
# t represing identification number so it doesnt influence much in the primary fuel-depedent feature and capacity.

# %%
# Dropping columns
df.drop(columns=["owner","url","name"],axis=1,inplace=True)

# %%
plt.figure(figsize=(13,7))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2013',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='generation_gwh_2013'>

# %%
plt.figure(figsize=(13,7))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2014',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='generation_gwh_2014'>

# %%
plt.figure(figsize=(13,7))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2015',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='generation_gwh_2015'>

# %%
plt.figure(figsize=(13,7))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2016',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='generation_gwh_2016'>

# %%
plt.figure(figsize=(13,7))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2017',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='generation_gwh_2017'>

# %%
plt.figure(figsize=(13,7))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2018',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='generation_gwh_2018'>

# %% [markdown]
# From this we can say that there is modication of primary fuel in the corresponding years. Majority of the primary fuel used in generation_gwh_2013 -Nuclear Fuel
#
# Majority of the primary fuel used in generation_gwh_2014 -Nuclear Fuel
#
# Majority of the primary fuel used in generation_gwh_2015 - Nuclear Fuel
#
# Majority of the primary fuel used in generation_gwh_2016 -coal
#
# Majority of the primary fuel used in generation_gwh_2017 -Coal
#
# Majority of the primary fuel used in generation_gwh_2018 - Coal

# %% [markdown]
# # Encoding:

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# With the help of label encoder encoding the categorical columns into numerical columns.

# %%
encoder = LabelEncoder()
df['primary_fuel'] = encoder.fit_transform(df['primary_fuel'])
df['geolocation_source'] = encoder.fit_transform(df['geolocation_source'])
df['source'] = encoder.fit_transform(df['source'])
df['country'] = encoder.fit_transform(df['source'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13298 entries, 0 to 511
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              13298 non-null  int64
#  1   capacity_mw          13298 non-null  float64
#  2   latitude             13298 non-null  float64
#  3   longitude            13298 non-null  float64
#  4   primary_fuel         13298 non-null  int32
#  5   commissioning_year   13298 non-null  float64
#  6   source               13298 non-null  int32
#  7   geolocation_source   13298 non-null  int32
#  8   generation_gwh_2013  13298 non-null  float64
#  9   generation_gwh_2014  13298 non-null  float64
#  10  generation_gwh_2015  13298 non-null  float64
#  11  generation_gwh_2016  13298 non-null  float64
#  12  generation_gwh_2017  13298 non-null  float64
#  13  generation_gwh_2018  13298 non-null  float64
#  14  generation_gwh_2019  13298 non-null  object
# dtypes: float64(10), int32(3), int64(1), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# Now all the columns have numerical values.

# %%
df.drop("generation_gwh_2019",axis=1,inplace=True)

# %% [markdown]
# # Corelation:

# %%
df.corr()
# Out:
#                       country  capacity_mw  latitude  longitude  primary_fuel  \
# country              1.000000    -0.146256  0.754707  -0.905545      0.181774
# capacity_mw         -0.146256     1.000000 -0.080457   0.127177     -0.362530
# latitude             0.754707    -0.080457  1.000000  -0.775378      0.099356
# longitude           -0.905545     0.127177 -0.775378   1.000000     -0.166259
# primary_fuel         0.181774    -0.362530  0.099356  -0.166259      1.000000
# commissioning_year  -0.014678    -0.098155 -0.056628   0.031260      0.444105
# source               1.000000    -0.146256  0.754707  -0.905545      0.181774
# geolocation_source   0.351768     0.070508  0.683962  -0.451723     -0.047139
# generation_gwh_2013  0.004862     0.667360 -0.023424   0.004637     -0.202419
# generation_gwh_2014 -0.103831     0.795624 -0.052091   0.092221     -0.243460
# generation_gwh_2015 -0.110180     0.814142 -0.054830   0.097495     -0.252103
# generation_gwh_2016 -0.118652     0.813790 -0.058400   0.103669     -0.246693
# generation_gwh_2017 -0.125241     0.812694 -0.060082   0.109114     -0.244411
# generation_gwh_2018 -0.128894     0.822004 -0.060251   0.112126     -0.248388
#
#                      commissioning_year    source  geolocation_source  \
# country                       -0.014678  1.000000            0.351768
# capacity_mw                   -0.098155 -0.146256            0.070508
# latitude                      -0.056628  0.754707            0.683962
# longitude                      0.031260 -0.905545           -0.451723
# primary_fuel                   0.444105  0.181774           -0.047139
# commissioning_year             1.000000 -0.014678           -0.027892
# source                        -0.014678  1.000000            0.351768
# geolocation_source            -0.027892  0.351768            1.000000
# generation_gwh_2013           -0.104594  0.004862           -0.010392
# generation_gwh_2014           -0.090152 -0.103831            0.048224
# generation_gwh_2015           -0.081626 -0.110180            0.051124
# generation_gwh_2016           -0.071632 -0.118652            0.053765
# generation_gwh_2017           -0.068023 -0.125241            0.056035
# generation_gwh_2018           -0.064800 -0.128894            0.059480
#
#                      generation_gwh_2013  generation_gwh_2014  \
# country                         0.004862            -0.103831
# capacity_mw                     0.667360             0.795624
# latitude                       -0.023424            -0.052091
# longitude                       0.004637             0.092221
# primary_fuel                   -0.202419            -0.243460
# commissioning_year             -0.104594            -0.090152
# source                          0.004862            -0.103831
# geolocation_source             -0.010392             0.048224
# generation_gwh_2013             1.000000             0.827239
# generation_gwh_2014             0.827239             1.000000
# generation_gwh_2015             0.800063             0.969961
# generation_gwh_2016             0.767244             0.937811
# generation_gwh_2017             0.769788             0.919601
# generation_gwh_2018             0.739651             0.912850
#
#                      generation_gwh_2015  generation_gwh_2016  \
# country                        -0.110180            -0.118652
# capacity_mw                     0.814142             0.813790
# latitude                       -0.054830            -0.058400
# longitude                       0.097495             0.103669
# primary_fuel                   -0.252103            -0.246693
# commissioning_year             -0.081626            -0.071632
# source                         -0.110180            -0.118652
# geolocation_source              0.051124             0.053765
# generation_gwh_2013             0.800063             0.767244
# generation_gwh_2014             0.969961             0.937811
# generation_gwh_2015             1.000000             0.964323
# generation_gwh_2016             0.964323             1.000000
# generation_gwh_2017             0.942955             0.969369
# generation_gwh_2018             0.941790             0.956269
#
#                      generation_gwh_2017  generation_gwh_2018
# country                        -0.125241            -0.128894
# capacity_mw                     0.812694             0.822004
# latitude                       -0.060082            -0.060251
# longitude                       0.109114             0.112126
# primary_fuel                   -0.244411            -0.248388
# commissioning_year             -0.068023            -0.064800
# source                         -0.125241            -0.128894
# geolocation_source              0.056035             0.059480
# generation_gwh_2013             0.769788             0.739651
# generation_gwh_2014             0.919601             0.912850
# generation_gwh_2015             0.942955             0.941790
# generation_gwh_2016             0.969369             0.956269
# generation_gwh_2017             1.000000             0.966072
# generation_gwh_2018             0.966072             1.000000

# %%
plt.figure(figsize=(25,20))
sns.heatmap(df.corr(),annot=True,linewidths=.25)
# Out:
# <Axes: >

# %% [markdown]
#  observation: The latitude and longitude column has related to each other with negatice corelation of 78%.
#
# For capacity_mw: 'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018', All these columns have positive corelation with capacity_mw.
#
# Source and longitude column has negative corelation with 91%.

# %%
#To see the co-relation among the columns with respect to region:
plt.figure(figsize=(20,15),facecolor="pink")
plotnumber=1
for column in df:
    if plotnumber<=24:
        ax=plt.subplot(6,4,plotnumber)
        sns.scatterplot(x=column,y="primary_fuel",data=df)
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
#To see the co-relation among the columns with respect to region:
plt.figure(figsize=(20,15),facecolor="pink")
plotnumber=1
for column in df:
    if plotnumber<=24:
        ax=plt.subplot(6,4,plotnumber)
        sns.scatterplot(x=column,y="capacity_mw",data=df)
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From this scatterplot we can there is positive corelation in the generation_gwh to all the years for the capacity feature.

# %% [markdown]
# # Outliers:

# %% [markdown]
# # Zscore

# %%
from scipy.stats import zscore

z=np.abs(zscore(df))

print(np.where(z>3))
# Out:
# (array([    2,     2,     4, ..., 13297, 13297, 13297], dtype=int64), array([0, 6, 1, ..., 3, 6, 7], dtype=int64))

# %%
df_1=df[(z<3).all(axis=1)]
print("with outliers::",df.shape)
print("After removing outliers::",df_1.shape)
# Out:
# with outliers:: (13298, 14)
# After removing outliers:: (11759, 14)

# %% [markdown]
# # IQR

# %%
from scipy import stats 
IQR = stats.iqr(df) 
IQR
# Out:
# 182.0

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
df_out = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
print(df_out.shape)
# Out:
# (10926, 14)

# %% [markdown]
# Chossing the IQR for outlier removal.

# %%
df=df_out

# %% [markdown]
# # Skewness:

# %%
df.skew()
# Out:
# country               -3.270392
# capacity_mw            3.857738
# latitude              -3.492939
# longitude              2.667932
# primary_fuel          -0.699027
# commissioning_year    -2.236079
# source                -3.270392
# geolocation_source    -3.648457
# generation_gwh_2013    3.508944
# generation_gwh_2014    3.466363
# generation_gwh_2015    3.477890
# generation_gwh_2016    3.374792
# generation_gwh_2017    3.259350
# generation_gwh_2018    3.146027
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
PT=PowerTransformer()
for i in df.columns:
    if abs(df.loc[:,i].skew())>0.5:
        df.loc[:,i]=PT.fit_transform(df.loc[:,i].values.reshape(-1,1))

# %% [markdown]
# # Splitting The Dataset Into Feature and Target:

# %%
#Importing the neccessary libraries and model for further creation of the model:
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import SVR

from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

from sklearn.model_selection import GridSearchCV

# %%
# Splitting data in target and dependent feature
X2 = df.drop(['primary_fuel'], axis =1)
Y2= df['primary_fuel']

# %%
# Splitting data in target and dependent feature
X = df.drop(['capacity_mw'], axis =1)
Y = df['capacity_mw']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10926 entries, 0 to 510
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              10926 non-null  float64
#  1   latitude             10926 non-null  float64
#  2   longitude            10926 non-null  float64
#  3   primary_fuel         10926 non-null  float64
#  4   commissioning_year   10926 non-null  float64
#  5   source               10926 non-null  float64
#  6   geolocation_source   10926 non-null  float64
#  7   generation_gwh_2013  10926 non-null  float64
#  8   generation_gwh_2014  10926 non-null  float64
#  9   generation_gwh_2015  10926 non-null  float64
#  10  generation_gwh_2016  10926 non-null  float64
#  11  generation_gwh_2017  10926 non-null  float64
#  12  generation_gwh_2018  10926 non-null  float64
# dtypes: float64(13)
# memory usage: 1.2 MB

# %% [markdown]
# # Standardisation:

# %%
from sklearn.preprocessing import MinMaxScaler

sc=MinMaxScaler()
x_scaled=sc.fit_transform(X)

# %% [markdown]
# # Random State selection:

# %%
maxR2_Score=0
maxRS=0
for i in range(1,500):
    x_train,x_test,y2_train,y2_test = train_test_split(x_scaled,Y,test_size=.25,random_state=i)
    LR = LinearRegression()
    LR.fit(x_train, y2_train)
    predrf = LR.predict(x_test)
    score = r2_score(y2_test, predrf)
    if score>maxR2_Score:
        maxR2_Score=score
        maxRS=i
print("Best accuracy is",maxR2_Score," on Random_state ",maxRS)
# Out:
# Best accuracy is 0.3219001015907217  on Random_state  489

# %%
# spliting data 70% for train and 30% for test
x_train,x_test,y_train,y_test=train_test_split(x_scaled,Y,test_size=.25,random_state=maxRS)

# %% [markdown]
# # Model:

# %%
model=[LinearRegression(),RandomForestRegressor(),DecisionTreeRegressor(),KNeighborsRegressor(),GradientBoostingRegressor(),Ridge(),SVR()]

# %%
for m in model:
    print('Accuracy score:', m)
    m.fit(x_train,y_train)
    pred = m.predict(x_test)
    print("R2 Score:                ", r2_score(y_test,pred))
    print("Mean Absolute Error:     ", mean_absolute_error(y_test,pred))
    print("Mean Squared error:      ", mean_squared_error(y_test,pred))
    print("Root Mean Squared Error: ", np.sqrt(mean_squared_error(y_test,pred)))
    score=cross_val_score(m,X,Y,cv=5)
    print(score)
    print("cross validation score:  ",score.mean())
    print("Difference between R2 score and cross validatio score is :  ",r2_score(y_test,pred)-abs(score.mean()))
    print('*'*50)
# Out:
# Accuracy score: LinearRegression()
# R2 Score:                 0.3219001015907217
# Mean Absolute Error:      0.6675401123109789
# Mean Squared error:       0.6904926177277687
# Root Mean Squared Error:  0.8309588544132427
# [0.2973045  0.23785991 0.23491021 0.20754007 0.27686423]
# cross validation score:   0.2508957832360287
# Difference between R2 score and cross validatio score is :   0.07100431835469301
# **************************************************
# Accuracy score: RandomForestRegressor()
# R2 Score:                 0.8446641819478067
# Mean Absolute Error:      0.21923578257626547
# Mean Squared error:       0.15817468176201654
# Root Mean Squared Error:  0.397711807420922
# [0.62188035 0.86393589 0.87291434 0.85307908 0.68699464]
# cross validation score:   0.7797608592394945
# Difference between R2 score and cross validatio score is :   0.06490332270831223
# **************************************************
# Accuracy score: DecisionTreeRegressor()
# R2 Score:                 0.7415995689492297
# Mean Absolute Error:      0.27818247276347746
# Mean Squared error:       0.26312286799745205
# Root Mean Squared Error:  0.512955035063944
# [0.39851799 0.74664649 0.77371181 0.75088438 0.5153964 ]
# cross validation score:   0.6370314141232084
# Difference between R2 score and cross validatio score is :   0.10456815482602133
# **************************************************
# Accuracy score: KNeighborsRegressor()
# R2 Score:                 0.8030123198004302
# Mean Absolute Error:      0.27478581704047156
# Mean Squared error:       0.20058775894259948
# Root Mean Squared Error:  0.4478702478872642
# [0.74868169 0.80952184 0.81245353 0.80235254 0.65394556]
# cross validation score:   0.7653910323007299
# Difference between R2 score and cross validatio score is :   0.037621287499700284
# **************************************************
# Accuracy score: GradientBoostingRegressor()
# R2 Score:                 0.8114933617302149
# Mean Absolute Error:      0.29829891675937326
# Mean Squared error:       0.19195172042247347
# Root Mean Squared Error:  0.4381229512619414
# [0.6316744  0.8187566  0.81414023 0.8277683  0.66367083]
# cross validation score:   0.7512020731647169
# Difference between R2 score and cross validatio score is :   0.060291288565498036
# **************************************************
# Accuracy score: Ridge()
# R2 Score:                 0.31120857493439613
# Mean Absolute Error:      0.6747451459071606
# Mean Squared error:       0.7013795390291145
# Root Mean Squared Error:  0.8374840529998853
# [0.29730187 0.23788307 0.23494222 0.20759108 0.27686575]
# cross validation score:   0.2509167975458527
# Difference between R2 score and cross validatio score is :   0.06029177738854341
# **************************************************
# Accuracy score: SVR()
# R2 Score:                 0.6440911269783152
# Mean Absolute Error:      0.44792401838653634
# Mean Squared error:       0.36241334054433855
# Root Mean Squared Error:  0.6020077578772042
# [0.72134722 0.69319142 0.70911966 0.71078444 0.62458265]
# cross validation score:   0.6918050794223
# Difference between R2 score and cross validatio score is :   -0.0477139524439848
# **************************************************

# %% [markdown]
# # Top Model:1

# %% [markdown]
# Accuracy score: KNeighborsRegressor()
#
# R2 Score:                 0.8030123198004302
#
# cross validation score:   0.7653910323007299
#
# Difference between R2 score and cross validatio score is :   0.037621287499700284

# %% [markdown]
# # Top Model:2

# %% [markdown]
# Accuracy score: RandomForestRegressor()
#
# R2 Score:                 0.8434045107626373
#
# cross validation score:   0.7833330313791352
#
# Difference between R2 score and cross validatio score is :   0.0600714793835021

# %% [markdown]
# # Saving the Model:

# %%
import joblib
joblib.dump(RandomForestRegressor(),"Global power plant.pkl")
# Out:
# ['Global power plant.pkl']

# %%
#End of the Project
