# %% [markdown]
# # Insurance Claim Fraud Detection

# %% [markdown]
# # Project Description

# %% [markdown]
# Insurance fraud is a huge problem in the industry. It's difficult to identify fraud claims. Machine Learning is in a unique position to help the Auto Insurance industry with this problem.
# In this project, you are provided a dataset which has the details of the insurance policy along with the customer details. It also has the details of the accident on the basis of which the claims have been made.
# In this example, you will be working with some auto insurance data to demonstrate how you can create a predictive model that predicts if an insurance claim is fraudulent or not.

# %% [markdown]
# # Independent Variables

# %% [markdown]
# 1.	months_as_customer: Number of months of patronage
#
# 2.	age: the length of time a customer has lived or a thing has existed
#
# 3.	policy_number: It is a unique id given to the customer, to track the subscription status and other details of customer
#
# 4.	policy_bind_date:date which document that is given to customer after we accept your proposal for insurance
#
# 5.	policy_state: This identifies who is the insured, what risks or property are covered, the policy limits, and the policy period
#
# 6.	policy_csl: is basically Combined Single Limit
#
# 7.	policy_deductable: the amount of money that a customer is responsible for paying toward an insured loss
#
# 8.	policy_annual_premium: This means the amount of Regular Premium payable by the Policyholder in a Policy Year
#
# 9.	umbrella_limit: This means extra insurance that provides protection beyond existing limits and coverages of other policies
#
# 10.	insured_zip: It is the zip code where the insurance was made
#
# 11.	insured_sex: This refres to either of the two main categories (male and female) into which customer are divided on the basis of their reproductive functions
#
# 12.	insured_education_level: This refers to the Level of education of the customer
#
# 13.	insured_occupation: This refers Occupation of the customer
#
# 14.	insured_hobbies: This refers to an activity done regularly by customer in his/her leisure time for pleasure.
#
# 15.	insured_relationship: This whether customer is: single; or. married; or. in a de facto relationship (that is, living together but not married); or. in a civil partnership
#
# 16.	capital-gains: This refers to profit accrued due to insurance premium
#
# 17.	capital-loss: This refers to the losses incurred due to insurance claims
#
# 18.	incident_date: This refers to the date which claims where made by customers
#
# 19.	incident_type: This refers to the type of claim/vehicle damage made by customer
#
# 20.	collision_type: This refers to the area of damage on the vehicle
#
# 21.	incident_severity: This refers to the extent/level of damage
#
# 22.	authorities_contacted: This refers to the government agencies that were contacted after damage
#
# 23.	incident_state: This refers to the state at which the accident happened
#
# 24.	incident_city: This refers to the city at which the accident happened
#
# 25.	1ncident_location: This refers to the location at which the accident happened
#
# 26.	incident_hour_of_the_day: The period of the day which accident took place
#
# 27.	number_of_vehicles_involved: This refers to number of vehicles involved the accident
#
# 28.	property_damage: This refers to whether property was damaged or not
#
# 29.	bodily_injuries: This refers to injuries sustained
#
# 30.	witnesses: This refers to the number of witnesses involved
#
# 31.	police_report_available: This refers to whether the report on damage was documented or not
#
# 32.	total_claim_amount: This refers to the financial implications involved in claims
#
# 33.	injury_claim: This refers to physical injuries sustained
#
# 34.	property_claim: This refers to property damages during incident
#
# 35.	vehicle_claim: This refers to property damages during incident
#
# 36.	auto_make: This refers to the make of the vehicle
#
# 37.	auto_model: This refers to the model of the vehicle
#
# 38.	auto_year: This refers to the year which the vehicle was manufactured
#
# 39.	_c39:
#
# 40.	fraud_reported

# %% [markdown]
# Dataset Link-
# https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Insurance%20Claim%20Fraud%20Detection/Automobile_insurance_fraud.csv

# %% [markdown]
# # EXPLORATION OF DATASET:

# %%
#Importing necessary libraries for analysis:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
#Downloading the raw data and loading into dataframe with the help of pandas library
df=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Insurance%20Claim%20Fraud%20Detection/Automobile_insurance_fraud.csv")

# %%
#For viewing the first 5 columns in given dataset
df.head(5)
# Out:
#    328  48  521585  17-10-2014  OH   250/500  1000  1406.91        0  466132  \
# 0  228  42  342868  27-06-2006  IN   250/500  2000  1197.22  5000000  468176
# 1  134  29  687698  06-09-2000  OH   100/300  2000  1413.14  5000000  430632
# 2  256  41  227811  25-05-1990  IL   250/500  2000  1415.74  6000000  608117
# 3  228  44  367455  06-06-2014  IL  500/1000  1000  1583.91  6000000  610706
# 4  256  39  104594  12-10-2006  OH   250/500  1000  1351.10        0  478456
#
#    ...  2 YES.1  71610  6510 13020  52080       Saab    92x  2004  Y
# 0  ...  0     ?   5070   780   780   3510   Mercedes   E400  2007  Y
# 1  ...  3    NO  34650  7700  3850  23100      Dodge    RAM  2007  N
# 2  ...  2    NO  63400  6340  6340  50720  Chevrolet  Tahoe  2014  Y
# 3  ...  1    NO   6500  1300   650   4550     Accura    RSX  2009  N
# 4  ...  2    NO  64100  6410  6410  51280       Saab     95  2003  Y
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['328', '48', '521585', '17-10-2014', 'OH', '250/500', '1000', '1406.91',
#        '0', '466132', 'MALE', 'MD', 'craft-repair', 'sleeping', 'husband',
#        '53300', '0.1', '25-01-2015', 'Single Vehicle Collision',
#        'Side Collision', 'Major Damage', 'Police', 'SC', 'Columbus',
#        '9935 4th Drive', '5', '1', 'YES', '1.1', '2', 'YES.1', '71610', '6510',
#        '13020', '52080', 'Saab', '92x', '2004', 'Y'],
#       dtype='object')

# %%
df.columns=["months_as_customerage","Age","policy_number","policy_bind_date","policy_state","policy_csl","policy_deductable","policy_annual_premium","umbrella_limit","insured_zip","insured_sex","insured_education_level","insured_occupation","insured_hobbies","insured_relationship","capital-gains","capital-loss","incident_date","incident_type","collision_type","incident_severity","authorities_contacted","incident_state","incident_city","incident_location","incident_hour_of_the_day","number_of_vehicles_involved","property_damage","bodily_injuries","witnesses","police_report_available","total_claim_amount","injury_claim","property_claim","vehicle_claim","auto_make","auto_model","auto_year","fraud_reported"]

# %%
df.head(5)
# Out:
#    months_as_customerage  Age  policy_number policy_bind_date policy_state  \
# 0                    228   42         342868       27-06-2006           IN
# 1                    134   29         687698       06-09-2000           OH
# 2                    256   41         227811       25-05-1990           IL
# 3                    228   44         367455       06-06-2014           IL
# 4                    256   39         104594       12-10-2006           OH
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               2000                1197.22         5000000
# 1    100/300               2000                1413.14         5000000
# 2    250/500               2000                1415.74         6000000
# 3   500/1000               1000                1583.91         6000000
# 4    250/500               1000                1351.10               0
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# ...

# %%
#To know about the no of rows and columns in the dataset
df.shape
# Out:
# (999, 39)

# %% [markdown]
# There are 999 rows and 39 columns in the dataset.

# %%
#To know more about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customerage        999 non-null    int64
#  1   Age                          999 non-null    int64
#  2   policy_number                999 non-null    int64
#  3   policy_bind_date             999 non-null    object
#  4   policy_state                 999 non-null    object
#  5   policy_csl                   999 non-null    object
#  6   policy_deductable            999 non-null    int64
#  7   policy_annual_premium        999 non-null    float64
#  8   umbrella_limit               999 non-null    int64
#  9   insured_zip                  999 non-null    int64
#  10  insured_sex                  999 non-null    object
#  11  insured_education_level      999 non-null    object
#  12  insured_occupation           999 non-null    object
# ...

# %%
cat_col = df.select_dtypes(include=['object']).columns
print("Categorical columns are:",cat_col)
print("\nThe count of categoricdal columns are:",len(cat_col))
# Out:
# Categorical columns are: Index(['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'incident_date', 'incident_type',
#        'collision_type', 'incident_severity', 'authorities_contacted',
#        'incident_state', 'incident_city', 'incident_location',
#        'property_damage', 'police_report_available', 'auto_make', 'auto_model',
#        'fraud_reported'],
#       dtype='object')
#
# The count of categoricdal columns are: 21

# %%
num_col = df.select_dtypes(include=['int64','float64']).columns
print("Numerical columns are:",num_col)
print("\nThe count of Numerical Columns are",len(num_col))
# Out:
# Numerical columns are: Index(['months_as_customerage', 'Age', 'policy_number', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip',
#        'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
#        'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#        'auto_year'],
#       dtype='object')
#
# The count of Numerical Columns are 18

# %%
#Unique values in the column
below_5=[]
below_10=[]
below_20=[]
below_30=[]
below_40=[]
for i in df.columns:
    print("Unique Value count of",i,"column:",len(df[i].unique()))
    if (len(df[i].unique())<5):
        below_5.append(i)
    if (5<len(df[i].unique())<10):
        below_10.append(i)
    if (10<len(df[i].unique())<20):
        below_20.append(i)
    if (20<len(df[i].unique())<30):
        below_30.append(i)
    if (30<len(df[i].unique())<40):
        below_40.append(i)
# Out:
# Unique Value count of months_as_customerage column: 391
# Unique Value count of Age column: 46
# Unique Value count of policy_number column: 999
# Unique Value count of policy_bind_date column: 950
# Unique Value count of policy_state column: 3
# Unique Value count of policy_csl column: 3
# Unique Value count of policy_deductable column: 3
# Unique Value count of policy_annual_premium column: 990
# Unique Value count of umbrella_limit column: 11
# Unique Value count of insured_zip column: 994
# Unique Value count of insured_sex column: 2
# Unique Value count of insured_education_level column: 7
# Unique Value count of insured_occupation column: 14
# Unique Value count of insured_hobbies column: 20
# Unique Value count of insured_relationship column: 6
# Unique Value count of capital-gains column: 338
# Unique Value count of capital-loss column: 354
# Unique Value count of incident_date column: 60
# Unique Value count of incident_type column: 4
# ...

# %%
print("There are",len(below_5),"columns which has unique value count less than 5","\n""The columns are",below_5)
print("\n")
print("There are",len(below_10),"columns which has unique value count less than 10","\n""The columns are",below_10)
print("\n")
print("There are",len(below_20),"columns which has unique value count less than 20","\n""The columns are",below_20)
print("\n")
print("There are",len(below_30),"columns which has unique value count less than 30","\n""The columns are",below_30)
print("\n")
print("There are",len(below_40),"columns which has unique value count less than 40","\n""The columns are",below_40)
print("\n")
# Out:
# There are 13 columns which has unique value count less than 5
# The columns are ['policy_state', 'policy_csl', 'policy_deductable', 'insured_sex', 'incident_type', 'collision_type', 'incident_severity', 'number_of_vehicles_involved', 'property_damage', 'bodily_injuries', 'witnesses', 'police_report_available', 'fraud_reported']
#
#
# There are 4 columns which has unique value count less than 10
# The columns are ['insured_education_level', 'insured_relationship', 'incident_state', 'incident_city']
#
#
# There are 3 columns which has unique value count less than 20
# The columns are ['umbrella_limit', 'insured_occupation', 'auto_make']
#
#
# There are 2 columns which has unique value count less than 30
# The columns are ['incident_hour_of_the_day', 'auto_year']
#
#
# There are 1 columns which has unique value count less than 40
# The columns are ['auto_model']

# %% [markdown]
# # Identifying the missing values:

# %%
#To know about the missing values in the given dataset
df.isnull().sum()
# Out:
# months_as_customerage          0
# Age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...

# %% [markdown]
# While going through the unique values in the column we can see there in question mark sign which represents the NAN value so repelacing that with the NAN.

# %%
df.isin(['?']).sum()
# Out:
# months_as_customerage            0
# Age                              0
# policy_number                    0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_date                    0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# authorities_contacted            0
# incident_state                   0
# incident_city                    0
# incident_location                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# ...

# %%
# replace ? with Nan
df=df.replace('?',np.nan)

# %%
#Finding the missing values
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values],axis =1,keys =['Missing Values','% Missing data']))
# Out:
#                              Missing Values  % Missing data
# property_damage                         360       36.036036
# police_report_available                 343       34.334334
# collision_type                          178       17.817818
# auto_model                                0        0.000000
# auto_make                                 0        0.000000
# vehicle_claim                             0        0.000000
# property_claim                            0        0.000000
# injury_claim                              0        0.000000
# total_claim_amount                        0        0.000000
# incident_severity                         0        0.000000
# witnesses                                 0        0.000000
# bodily_injuries                           0        0.000000
# auto_year                                 0        0.000000
# number_of_vehicles_involved               0        0.000000
# incident_hour_of_the_day                  0        0.000000
# ...

# %%
df.shape
# Out:
# (999, 39)

# %%
df_new=df.dropna()
df_new.shape
# Out:
# (339, 39)

# %% [markdown]
# While dropping the null columns there is huge data loss in the dataset.So following the imputation technique to fill the missing values.

# %% [markdown]
# [collision_type,police_report_available,property_damage]-All these columns comes under categorical column imputing with mode value.

# %%
df["collision_type"].fillna(df["collision_type"].mode()[0], inplace=True)
df["police_report_available"].fillna(df["police_report_available"].mode()[0], inplace=True)
df["property_damage"].fillna(df["property_damage"].mode()[0], inplace=True)

# %%
plt.figure(figsize = (16,5))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# There is no missing values in the dataset.We can further proceed for the futher data analysis.

# %% [markdown]
# # Statistical Analysis of the dataset:

# %%
#To know more about the statistical description of the dataset
df.describe()
# Out:
#        months_as_customerage         Age  policy_number  policy_deductable  \
# count             999.000000  999.000000     999.000000         999.000000
# mean              203.829830   38.938939  546263.326326        1136.136136
# std               115.103809    9.140370  257190.576942         612.155989
# min                 0.000000   19.000000  100804.000000         500.000000
# 25%               115.500000   32.000000  335913.500000         500.000000
# 50%               199.000000   38.000000  533940.000000        1000.000000
# 75%               276.000000   44.000000  759459.500000        2000.000000
# max               479.000000   64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count             999.000000    9.990000e+02     999.000000     999.000000
# mean             1256.255495    1.102102e+06  501249.605606   25097.897898
# ...

# %% [markdown]
# Observation:
#
# 1]The count of all the columns are equal there is no missing values in the dataset.
#
# 2]The mean value is greater than the median it represents the right skewed distribution of data.The columns which has the this kind of distribution are[policy_number,policy_deductable,umbrella_limit,insured_zip,capital-gains,witnesses,total_claim_amount,injury_claim,property_claim,]
#
# 3]The mean value is lower than the median it represents the left skewed distribution of data.The columns which has this kind of the distribution are[months_as_customerage,capital-loss,incident_hour_of_the_day,number_of_vehicles_involved,bodily_injuries,vehicle_claim]
#
# 4]The columns may have normal distribution are [Age,policy_annual_premium,auto_year]

# %%
#To see the distribution among the columns:
plt.figure(figsize=(20,15),facecolor="pink")
plotnumber=1
for column in num_col:
    if plotnumber<=24:
        ax=plt.subplot(6,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From this distplot we can see the distribution of data:

# %% [markdown]
# 'months_as_customerage'-Median part is deviated into two
# 'Age'- mean to median 38 value is revolved it may have normal distribution
# 'policy_number',it has divation in left ,middle,right.
# There are many ups and down in the distrubution almost all the distribution of the dataset has the own deviations we have to find out the skewness level.

# %%
df.skew()
# Out:
# months_as_customerage          0.364615
# Age                            0.481461
# policy_number                  0.038684
# policy_deductable              0.477027
# policy_annual_premium          0.006022
# umbrella_limit                 1.805104
# insured_zip                    0.815086
# capital-gains                  0.481352
# capital-loss                  -0.389813
# incident_hour_of_the_day      -0.037615
# number_of_vehicles_involved    0.501009
# bodily_injuries                0.014799
# witnesses                      0.020923
# total_claim_amount            -0.592958
# injury_claim                   0.264131
# property_claim                 0.380670
# vehicle_claim                 -0.619480
# auto_year                     -0.048812
# dtype: float64

# %% [markdown]
# sklewness above +/- need to treated.

# %% [markdown]
# # Visualisation: Univariate and bivariate analysis

# %% [markdown]
# # Dependent Feature:fraud_reported - yes or no

# %%
cat_col
# Out:
# Index(['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'incident_date', 'incident_type',
#        'collision_type', 'incident_severity', 'authorities_contacted',
#        'incident_state', 'incident_city', 'incident_location',
#        'property_damage', 'police_report_available', 'auto_make', 'auto_model',
#        'fraud_reported'],
#       dtype='object')

# %%
#univariate analysis
#For the policy_state column:
df['policy_state'].unique()
# Out:
# array(['IN', 'OH', 'IL'], dtype=object)

# %%
#Univariate analysis
plt.figure(figsize=(14,4))
sns.countplot(x="policy_state",data=df)
plt.title(" policy_state Column")
plt.show()

# %%
(df['policy_state'].value_counts())/(len(df))*100
# Out:
# OH    35.135135
# IL    33.833834
# IN    31.031031
# Name: policy_state, dtype: float64

# %% [markdown]
# From this we can see that almost all the policy states are in the range not much difference between them OH-35% and IN-33%.

# %%
#BiVariate analysis.
plt.figure(figsize=(20,6))
sns.countplot(x="policy_state",hue="fraud_reported",data=df)
plt.title("policy_state and fraud_reported ")
plt.show()

# %% [markdown]
# From this viz,We can say that OH and IL is not fraud reported.

# %%
#For the policy_csl column:
df['policy_csl'].unique()
# Out:
# array(['250/500', '100/300', '500/1000'], dtype=object)

# %%
#Univariate analysis
plt.figure(figsize=(14,4))
sns.countplot(x="policy_csl",data=df)
plt.title(" policy_csl Column")
plt.show()

# %%
(df['policy_csl'].value_counts())/(len(df))*100
# Out:
# 250/500     35.035035
# 100/300     34.934935
# 500/1000    30.030030
# Name: policy_csl, dtype: float64

# %% [markdown]
# From this we can see that almost all the policy csl are in the range not much difference between them 240/100-35% and 100/300-33%.

# %%
#BiVariate analysis.Workclass vs Income
plt.figure(figsize=(20,6))
sns.countplot(x="policy_csl",hue="fraud_reported",data=df)
plt.title("policy_csl and fraud_reported ")
plt.show()

# %% [markdown]
# Majority fraud reportedd is not in the policy csl state.

# %%
cat_col
# Out:
# Index(['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'incident_date', 'incident_type',
#        'collision_type', 'incident_severity', 'authorities_contacted',
#        'incident_state', 'incident_city', 'incident_location',
#        'property_damage', 'police_report_available', 'auto_make', 'auto_model',
#        'fraud_reported'],
#       dtype='object')

# %%
#For the insured_sex column:
df['insured_sex'].unique()
# Out:
# array(['MALE', 'FEMALE'], dtype=object)

# %%
#Univariate analysis
plt.figure(figsize=(14,4))
sns.countplot(x="insured_sex",data=df)
plt.title("Insured_sex Column")
plt.show()

# %% [markdown]
# Compartive to the males,females are higher in number to get insured.

# %%
#BiVariate analysis
plt.figure(figsize=(20,6))
sns.countplot(x="insured_sex",hue="fraud_reported",data=df)
plt.title("Insured_sex and fraud_reported ")
plt.show()

# %% [markdown]
# Females are in higher number to be insured.And they are not fraud reported.

# %%
#For the insured_education_level column:
df['insured_education_level'].unique()
# Out:
# array(['MD', 'PhD', 'Associate', 'Masters', 'High School', 'College',
#        'JD'], dtype=object)

# %%
#Univariate analysis
plt.figure(figsize=(14,4))
sns.countplot(x="insured_education_level",data=df)
plt.title("insured_education_level Column")
plt.show()

# %% [markdown]
# JD and High school mostly opted for the insurance.

# %%
#BiVariate analysis
plt.figure(figsize=(20,6))
sns.countplot(x="insured_education_level",hue="fraud_reported",data=df)
plt.title("Insured_education_level and fraud_reported ")
plt.show()

# %% [markdown]
# Mostly  of them are not fraud reported

# %%
#For the insured_education_level column:
df['insured_occupation'].unique()
# Out:
# array(['machine-op-inspct', 'sales', 'armed-forces', 'tech-support',
#        'prof-specialty', 'other-service', 'priv-house-serv',
#        'exec-managerial', 'protective-serv', 'transport-moving',
#        'craft-repair', 'handlers-cleaners', 'adm-clerical',
#        'farming-fishing'], dtype=object)

# %%
#Univariate analysis
plt.figure(figsize=(25,6))
sns.countplot(x="insured_occupation",data=df)
plt.title("insured_occupation Column")
plt.show()

# %% [markdown]
# machine-op-inspect pccupation people opted for the insurance more.

# %%
#BiVariate analysis
plt.figure(figsize=(20,6))
sns.countplot(x="insured_occupation",hue="fraud_reported",data=df)
plt.title("insured_occupation and fraud_reported ")
plt.show()

# %%
df['incident_date'].unique()
# Out:
# array(['21-01-2015', '22-02-2015', '10-01-2015', '17-02-2015',
#        '02-01-2015', '13-01-2015', '27-02-2015', '30-01-2015',
#        '05-01-2015', '06-01-2015', '15-02-2015', '22-01-2015',
#        '08-01-2015', '15-01-2015', '29-01-2015', '19-01-2015',
#        '01-01-2015', '10-02-2015', '11-01-2015', '24-02-2015',
#        '09-01-2015', '28-01-2015', '07-01-2015', '18-01-2015',
#        '28-02-2015', '12-02-2015', '24-01-2015', '03-01-2015',
#        '16-01-2015', '14-02-2015', '21-02-2015', '18-02-2015',
#        '26-02-2015', '17-01-2015', '27-01-2015', '11-02-2015',
#        '12-01-2015', '06-02-2015', '20-01-2015', '02-02-2015',
#        '20-02-2015', '08-02-2015', '23-02-2015', '01-03-2015',
#        '14-01-2015', '19-02-2015', '09-02-2015', '26-01-2015',
#        '23-01-2015', '31-01-2015', '03-02-2015', '01-02-2015',
#        '05-02-2015', '25-01-2015', '25-02-2015', '16-02-2015',
#        '13-02-2015', '04-02-2015', '07-02-2015', '04-01-2015'],
#       dtype=object)

# %% [markdown]
# All cases reported on the month of January and Feb of 2015, few in March only

# %%
#For the insured_education_level column:
df['incident_type'].unique()
# Out:
# array(['Vehicle Theft', 'Multi-vehicle Collision',
#        'Single Vehicle Collision', 'Parked Car'], dtype=object)

# %%
#Univariate analysis
plt.figure(figsize=(25,6))
sns.countplot(x="collision_type",data=df)
plt.title("collision_type Column")
plt.show()

# %% [markdown]
# Maximum Rear collision set opted for the insurance

# %%
#BiVariate analysis
plt.figure(figsize=(20,6))
sns.countplot(x="collision_type",hue="fraud_reported",data=df)
plt.title("insured_occupation and fraud_reported ")
plt.show()

# %%
df['incident_severity'].unique()
# Out:
# array(['Minor Damage', 'Major Damage', 'Total Loss', 'Trivial Damage'],
#       dtype=object)

# %%
#BiVariate analysis
plt.figure(figsize=(20,6))
sns.countplot(x="incident_severity",hue="fraud_reported",data=df)
plt.title("incident_severity and fraud_reported ")
plt.show()

# %% [markdown]
# # Major damage where fraud reported maximum occured.

# %%
#BiVariate analysis
plt.figure(figsize=(20,6))
sns.countplot(x="authorities_contacted",hue="fraud_reported",data=df)
plt.title("authorities_contacted and fraud_reported ")
plt.show()

# %%
#BiVariate analysis
plt.figure(figsize=(20,6))
sns.countplot(x="incident_state",hue="fraud_reported",data=df)
plt.title("incident_state and fraud_reported ")
plt.show()

# %%
#BiVariate analysis
plt.figure(figsize=(20,6))
sns.countplot(x="incident_city",hue="fraud_reported",data=df)
plt.title("incident_city and fraud_reported ")
plt.show()

# %%
#BiVariate analysis
plt.figure(figsize=(20,6))
sns.countplot(x="property_damage",hue="fraud_reported",data=df)
plt.title("property_damage and fraud_reported ")
plt.show()

# %%
#BiVariate analysis
plt.figure(figsize=(20,6))
sns.countplot(x="police_report_available",hue="fraud_reported",data=df)
plt.title("police_report_available and fraud_reported ")
plt.show()

# %%
#BiVariate analysis
plt.figure(figsize=(20,6))
sns.countplot(x="auto_make",hue="fraud_reported",data=df)
plt.title("auto_make and fraud_reported ")
plt.show()

# %% [markdown]
# # Fraud_Reported

# %%
plt.figure(figsize=(10,6))
plt.pie(df['fraud_reported'].value_counts()*100/len(df),labels=['NOT Fraud Reported', 'YES Fraud Reported'],autopct='%.2f%%')
plt.show()

# %%
(df["fraud_reported"].value_counts())/(len(df))*100
# Out:
# N    75.375375
# Y    24.624625
# Name: fraud_reported, dtype: float64

# %% [markdown]
# From this pie chart we can analayse that uptop 75% not fraud reported and only 25% are fraud reported for the insurance.

# %% [markdown]
# # Encoding:

# %% [markdown]
# Converting text values into numerical values

# %% [markdown]
# Converting the dependent feature column:
# Fraud Reported yes=1,No=0

# %%
#Replacing the fraud reported column:
df.replace({
    "fraud_reported":{'N':0,'Y':1}},inplace=True)

# %%
#Replacing the fraud reported column:
df.replace({
    "police_report_available":{'NO':0,'YES':1}},inplace=True)

# %%
#Converting the property_Area column with label Encoder:
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['policy_state']=le.fit_transform(df['policy_state'])
df['policy_deductable']=le.fit_transform(df['policy_deductable'])
df['insured_sex']=le.fit_transform(df['insured_sex'])
df['incident_type']=le.fit_transform(df['incident_type'])
df['number_of_vehicles_involved']=le.fit_transform(df['number_of_vehicles_involved'])
df['property_damage']=le.fit_transform(df['property_damage'])
df['bodily_injuries']=le.fit_transform(df['bodily_injuries'])
df['witnesses']=le.fit_transform(df['witnesses'])
df['insured_education_level']=le.fit_transform(df['insured_education_level'])

# %%
df = df.drop(columns = ['policy_number', 'policy_csl','insured_zip','policy_bind_date', 'incident_date', 'incident_location',
                        'auto_year'])

# %%
cat_col = df.select_dtypes(include=['object']).columns

# %%
for i in cat_col:
    df[i]=le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customerage        999 non-null    int64
#  1   Age                          999 non-null    int64
#  2   policy_state                 999 non-null    int32
#  3   policy_deductable            999 non-null    int64
#  4   policy_annual_premium        999 non-null    float64
#  5   umbrella_limit               999 non-null    int64
#  6   insured_sex                  999 non-null    int32
#  7   insured_education_level      999 non-null    int32
#  8   insured_occupation           999 non-null    int32
#  9   insured_hobbies              999 non-null    int32
#  10  insured_relationship         999 non-null    int32
#  11  capital-gains                999 non-null    int64
#  12  capital-loss                 999 non-null    int64
# ...

# %% [markdown]
# All the categorical values are converted into numerical values.

# %% [markdown]
# # Corelation:

# %%
df.corr()
# Out:
#                              months_as_customerage       Age  policy_state  \
# months_as_customerage                     1.000000  0.922018     -0.001611
# Age                                       0.922018  1.000000     -0.015729
# policy_state                             -0.001611 -0.015729      1.000000
# policy_deductable                         0.018445  0.020528      0.008167
# policy_annual_premium                     0.004355  0.013801      0.011733
# umbrella_limit                            0.016027  0.018613     -0.029034
# insured_sex                               0.059833  0.072347     -0.021789
# insured_education_level                  -0.001407  0.000442     -0.034988
# insured_occupation                        0.011078  0.018390     -0.029879
# insured_hobbies                          -0.095178 -0.082695     -0.040274
# insured_relationship                      0.071395  0.076375     -0.016826
# ...

# %%
plt.figure(figsize=(25,20))
sns.heatmap(df.corr(),annot=True,linewidths=.25)
# Out:
# <Axes: >

# %% [markdown]
# Observation:
#     *Incident type and no of vehicles involved has strong negative corelation between them.
#     *vehicle clain and total_claim amount column has strong postive relation upto 98%.
#     *property claim and total_claim amount column has strong postive reltion upto 81%.

# %% [markdown]
# To the fraud reported column not much postive corelation can be seen.

# %% [markdown]
# # Skewness handling:

# %%
plt.figure(figsize=(18,15))
for i in enumerate(df.columns):
    plt.subplot(8,4,i[0]+1)
    sns.distplot(df[i[1]],color='r')

# %%
Y=df[["fraud_reported"]]
df.drop("fraud_reported",axis=1,inplace=True)

# %%
df.skew()
# Out:
# months_as_customerage          0.364615
# Age                            0.481461
# policy_state                  -0.024326
# policy_deductable              0.063604
# policy_annual_premium          0.006022
# umbrella_limit                 1.805104
# insured_sex                    0.150802
# insured_education_level        0.001298
# insured_occupation            -0.060896
# insured_hobbies               -0.059941
# insured_relationship           0.076349
# capital-gains                  0.481352
# capital-loss                  -0.389813
# incident_type                  0.103399
# collision_type                -0.032150
# incident_severity              0.277762
# authorities_contacted         -0.120066
# incident_state                -0.147805
# incident_city                  0.047574
# incident_hour_of_the_day      -0.037615
# number_of_vehicles_involved    0.501009
# property_damage                0.867426
# bodily_injuries                0.014799
# ...

# %%
#Removing skewness of the data
from sklearn.preprocessing import PowerTransformer
PT=PowerTransformer()
for i in df.columns:
    if abs(df.loc[:,i].skew())>0.5:
        df.loc[:,i]=PT.fit_transform(df.loc[:,i].values.reshape(-1,1))

# %%
df.skew()
# Out:
# months_as_customerage          0.364615
# Age                            0.481461
# policy_state                  -0.024326
# policy_deductable              0.063604
# policy_annual_premium          0.006022
# umbrella_limit                -7.858869
# insured_sex                    0.150802
# insured_education_level        0.001298
# insured_occupation            -0.060896
# insured_hobbies               -0.059941
# insured_relationship           0.076349
# capital-gains                  0.481352
# capital-loss                  -0.389813
# incident_type                  0.103399
# collision_type                -0.032150
# incident_severity              0.277762
# authorities_contacted         -0.120066
# incident_state                -0.147805
# incident_city                  0.047574
# incident_hour_of_the_day      -0.037615
# number_of_vehicles_involved    0.353967
# property_damage                0.867426
# bodily_injuries                0.014799
# ...

# %% [markdown]
# # Outliers:

# %%
#To see the outliers among the columns:
plt.figure(figsize=(25,15),facecolor="pink")
plotnumber=1
for column in df:
    if plotnumber<=40:
        ax=plt.subplot(8,5,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # outliers removal:

# %% [markdown]
# # Z-Score:

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
print(np.where(z>3))
z_scoredf=df[(z<3).all(axis=1)]
print("with outliers::",df.shape)
print("After removing outliers::",z_scoredf.shape)
# Out:
# (array([228, 247, 289, 499, 762, 806], dtype=int64), array([ 4,  4,  5, 27,  4, 12], dtype=int64))
# with outliers:: (999, 31)
# After removing outliers:: (993, 31)

# %% [markdown]
# # IQR:

# %%
from scipy import stats 
IQR = stats.iqr(df) 
print(IQR)
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQRdf= df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
print(IQRdf.shape)
# Out:
# 10.0
# (70, 31)

# %% [markdown]
# Choosing the zscore for the outlier removal

# %%
z_scoredf=df

# %% [markdown]
# # Checking for the Imbalanced dataset in dependent feature:

# %%
Y.value_counts()
# Out:
# fraud_reported
# 0                 753
# 1                 246
# dtype: int64

# %% [markdown]
# There is imbalanced dataset in dependent feature.

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()

# %% [markdown]
# # Splitting The Dataset Into Feature and Target:

# %%
#Importing the neccessary libraries and model for further creation of the model:
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.linear_model import RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score
from sklearn.model_selection import cross_val_score

# %%
X=df

# %%
X,Y=sm.fit_resample(X,Y)

# %%
X.shape , Y.shape
# Out:
# ((1506, 31), (1506, 1))

# %% [markdown]
# Now the dataset looks balanced

# %% [markdown]
# # Multicolinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
scaled= sc.fit_transform(X)

VIF= pd.DataFrame()
VIF['features']=X.columns

VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(X.columns))]
VIF
# Out:
#                        features           vif
# 0         months_as_customerage      7.082314
# 1                           Age      7.067309
# 2                  policy_state      1.046702
# 3             policy_deductable      1.038713
# 4         policy_annual_premium      1.045368
# 5                umbrella_limit      1.025974
# 6                   insured_sex      1.050285
# 7       insured_education_level      1.043285
# 8            insured_occupation      1.026719
# 9               insured_hobbies      1.071145
# 10         insured_relationship      1.048478
# 11                capital-gains      1.041425
# 12                 capital-loss      1.059209
# 13                incident_type      5.938779
# 14               collision_type      1.059151
# 15            incident_severity      1.339755
# 16        authorities_contacted      1.099567
# 17               incident_state      1.058804
# 18                incident_city      1.036582
# ...

# %%
X.drop(columns=['total_claim_amount'],axis=1,inplace=True)

# %% [markdown]
# # Standardisation:

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(X)

# %%
# best Random_state
maxaccu=0
maxRS=0

for i in range(0,200):
    x_train,x_test,y_train,y_test= train_test_split(x_scaled,Y,random_state=i,test_size=.20)
    LR= LogisticRegression()
    LR.fit(x_train,y_train)
    pred= LR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxRS=i
print("Best accuracy is ",maxaccu,"on Random State =",maxRS)
# Out:
# Best accuracy is  0.847682119205298 on Random State = 59

# %% [markdown]
# # Model selection:

# %%
LR_model= LogisticRegression()
RD_model= RidgeClassifier()
DT_model= DecisionTreeClassifier()
SV_model= SVC()
KNR_model= KNeighborsClassifier()
RFC_model= RandomForestClassifier()
SGH_model= SGDClassifier()
Bag_model=BaggingClassifier()
ADA_model=AdaBoostClassifier()
GB_model= GradientBoostingClassifier()

model=[LR_model,RD_model,DT_model,SV_model,KNR_model,RFC_model,SGH_model,Bag_model,ADA_model,GB_model ]

# %%
for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    pred= m.predict(x_test)
    print('Accuracy_Score of ',m, 'is', accuracy_score(y_test,pred)*100)
    print('Confusion Matrix of ',m,' is \n', confusion_matrix(y_test,pred) )
    print(classification_report(y_test,pred))
    print('*'*50)
# Out:
# Accuracy_Score of  LogisticRegression() is 78.80794701986756
# Confusion Matrix of  LogisticRegression()  is
#  [[117  33]
#  [ 31 121]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.79       150
#            1       0.79      0.80      0.79       152
#
#     accuracy                           0.79       302
#    macro avg       0.79      0.79      0.79       302
# weighted avg       0.79      0.79      0.79       302
#
# **************************************************
# Accuracy_Score of  RidgeClassifier() is 79.13907284768213
# Confusion Matrix of  RidgeClassifier()  is
#  [[115  35]
#  [ 28 124]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.78       150
#            1       0.78      0.82      0.80       152
#
#     accuracy                           0.79       302
#    macro avg       0.79      0.79      0.79       302
# ...

# %% [markdown]
# # Cross Validation:

# %%
for i in model:
    print('Accuracy_Score of ',i, 'is', accuracy_score(y_test,i.predict(x_test))*100)
    print("cross Validation accuracy score of ",i ," is ",cross_val_score(i,X,Y,cv=5, scoring='accuracy').mean()*100)
    print("\n")
# Out:
# Accuracy_Score of  LogisticRegression() is 78.80794701986756
# cross Validation accuracy score of  LogisticRegression()  is  59.166574992849455
#
#
# Accuracy_Score of  RidgeClassifier() is 79.13907284768213
# cross Validation accuracy score of  RidgeClassifier()  is  78.55932762755496
#
#
# Accuracy_Score of  DecisionTreeClassifier() is 83.77483443708608
# cross Validation accuracy score of  DecisionTreeClassifier()  is  81.5465006270489
#
#
# Accuracy_Score of  SVC() is 83.77483443708608
# cross Validation accuracy score of  SVC()  is  57.63547556709423
#
#
# Accuracy_Score of  KNeighborsClassifier() is 73.17880794701986
# cross Validation accuracy score of  KNeighborsClassifier()  is  nan
#
#
# Accuracy_Score of  RandomForestClassifier() is 85.43046357615894
# cross Validation accuracy score of  RandomForestClassifier()  is  86.19678334910124
#
#
# Accuracy_Score of  SGDClassifier() is 75.49668874172185
# cross Validation accuracy score of  SGDClassifier()  is  53.71829002662207
# ...

# %% [markdown]
# # Top Model:1

# %% [markdown]
# Accuracy_Score of  GradientBoostingClassifier() is 86.42384105960265
#
# cross Validation accuracy score of  GradientBoostingClassifier()  is  85.20318584849619

# %% [markdown]
# # Hyperparameter Tuning:

# %%
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV

# %%
params= {"learning_rate"    : [0.01,.05,.1,.2,.3,.5 ] ,
         'n_estimators':[5,50,100,200,300,400],
         "max_depth"        : [ 3, 4, 5, 6, 8]
          }

# %%
GCV= GridSearchCV(GB_model,params,cv=5,scoring='accuracy', n_jobs=-1)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3, 0.5],
#                          'max_depth': [3, 4, 5, 6, 8],
#                          'n_estimators': [5, 50, 100, 200, 300, 400]},
#              scoring='accuracy')

# %%
GCV.best_estimator_
# Out:
# GradientBoostingClassifier(learning_rate=0.2, max_depth=6, n_estimators=200)

# %%
GCV.best_params_
# Out:
# {'learning_rate': 0.2, 'max_depth': 6, 'n_estimators': 200}

# %%
pred=GCV.best_estimator_.predict(x_test)
accuracy_score(y_test,pred)
# Out:
# 0.8708609271523179

# %% [markdown]
# # Confusion Matrix:

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
# Out:
# array([[129,  21],
#        [ 18, 134]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,pred),annot=True, fmt='d')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       150
#            1       0.86      0.88      0.87       152
#
#     accuracy                           0.87       302
#    macro avg       0.87      0.87      0.87       302
# weighted avg       0.87      0.87      0.87       302

# %% [markdown]
# # ROCCURVE:

# %%
from sklearn.metrics import RocCurveDisplay

# %%
RocCurveDisplay.from_estimator(GCV, x_test, y_test)

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(GCV.best_estimator_,"Insurance claiM fraud_Prediction.pkl")
# Out:
# ['Insurance claiM fraud_Prediction.pkl']

# %% [markdown]
# # End of the Project
